# %%
from ecmwf.geomaps import quick_plot

HRES_MSL = "../tests/data/hres_msl.grib"

# %% [markdown]
# ### Basic plotting without the need for an OO API

# %%
quick_plot.contour_lines(HRES_MSL)
quick_plot.show()
# Out:
# Magics-warning: description is not a known keyword
