# %% [markdown]
# # Coastlines and Projection

# %% [markdown]
# ## Import the package
# you may need to install the package
# pip install mapgpye
# from mapgpye import GeoMap

# %%
from ecmwf.geomaps import GeoMap

# %% [raw]
# ## Create your first map

# %%
geomap = GeoMap()

# %% [markdown]
# ## Add a coastlines object

# %%
geomap.coastlines()

# %% [markdown]
# ##  Call the show method to render the object
# The coastlines will be rendered using all the  defaut values on the default geographical area/projection ie over the globe on cylindrical projection : EPSG:4326

# %%
geomap.show()

# %% [markdown]
# ## Tailor your plot
#  -  Change the visual attributes of the coastlines
#  -  Add gridlines, borders, rivers

# %%
geomap = GeoMap()

geomap.coastlines(land_colour="cream")
geomap.gridlines(colour='red')

geomap.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/git/magpye/ecmwf/geomaps/action.py in wrapper(self, preset, z_index, *args, **kwargs)
#      50                 try:
# ---> 51                     mapped_key = valid_args[key]
#      52                 except KeyError:
#
# KeyError: 'colour'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/pj/33n_ljh12_nf6nbm78x1h5mr0000gn/T/ipykernel_9239/1743900791.py in <module>
#       2
#       3 geomap.coastlines(land_colour="cream")
# ----> 4 geomap.gridlines(colour='red')
#       5
#       6 geomap.show()
#
# ~/git/magpye/ecmwf/geomaps/action.py in wrapper(self, preset, z_index, *args, **kwargs)
#      51                     mapped_key = valid_args[key]
#      52                 except KeyError:
# ---> 53                     raise TypeError(
#      54                         f"{method.__name__}() got an unexpected keyword "
#      55                         f"argument '{key}'"
#
# TypeError: gridlines() got an unexpected keyword argument 'colour'
